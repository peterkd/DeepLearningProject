# %%
import tensorflow_hub as hub

# %%
elmo = hub.Module("https://tfhub.dev/google/elmo/2", trainable=True)

def ELMoEmbedding2(x):
    return elmo.signatures['default'](tf.squeeze(tf.cast(x, tf.string)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-cde853f53f7a> in <module>
# ----> 1 elmo = hub.Module("https://tfhub.dev/google/elmo/2", trainable=True)
#       2
#       3 def ELMoEmbedding2(x):
#       4     return elmo.signatures['default'](tf.squeeze(tf.cast(x, tf.string)))
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow_hub/module.py in __init__(self, spec, trainable, name, tags)
#     155     """
#     156     self._graph = tf.compat.v1.get_default_graph()
# --> 157     self._spec = as_module_spec(spec)
#     158     self._trainable = trainable
#     159
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow_hub/module.py in as_module_spec(spec)
#      28     return spec
#      29   elif isinstance(spec, str):
# ---> 30     return load_module_spec(spec)
#      31   else:
# ...
